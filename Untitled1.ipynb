# %%
import numpy as np 
import json
import pandas as pd

import numpy as np 
import json as js
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from datetime import datetime
import glob
import seaborn as sns
import re
import os

# %%
usCatergory = {}
with open('youtube_data/US_category_id.json') as file:
      usCatergory = json.load(file)

# %%
usCatergory
# Out:
# {'kind': 'youtube#videoCategoryListResponse',
#  'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJvJAAShlR6hM"',
#  'items': [{'kind': 'youtube#videoCategory',
#    'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKmPBggty2mZQ"',
#    'id': '1',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Film & Animation',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"',
#    'id': '2',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Autos & Vehicles',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxbknKFVe5Lmg"',
#    'id': '10',
#    'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#     'title': 'Music',
#     'assignable': True}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-oBJavSGkfDI"',
#    'id': '15',
# ...

# %%
type(usCatergory)
# Out:
# dict

# %%
usCatergory['etag']
# Out:
# '"m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJvJAAShlR6hM"'

# %%
usCatergory['items']
# Out:
# [{'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKmPBggty2mZQ"',
#   'id': '1',
#   'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#    'title': 'Film & Animation',
#    'assignable': True}},
#  {'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45ZTFR3a3NyTA"',
#   'id': '2',
#   'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#    'title': 'Autos & Vehicles',
#    'assignable': True}},
#  {'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxbknKFVe5Lmg"',
#   'id': '10',
#   'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#    'title': 'Music',
#    'assignable': True}},
#  {'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-oBJavSGkfDI"',
#   'id': '15',
#   'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#    'title': 'Pets & Animals',
#    'assignable': True}},
#  {'kind': 'youtube#videoCategory',
# ...

# %%
for obj in usCatergory['items']:
    print(type(obj))
    print(obj['id'] + "::" + obj['snippet']['title'])
# Out:
# <class 'dict'>
# 1::Film & Animation
# <class 'dict'>
# 2::Autos & Vehicles
# <class 'dict'>
# 10::Music
# <class 'dict'>
# 15::Pets & Animals
# <class 'dict'>
# 17::Sports
# <class 'dict'>
# 18::Short Movies
# <class 'dict'>
# 19::Travel & Events
# <class 'dict'>
# 20::Gaming
# <class 'dict'>
# 21::Videoblogging
# <class 'dict'>
# 22::People & Blogs
# <class 'dict'>
# 23::Comedy
# <class 'dict'>
# 24::Entertainment
# <class 'dict'>
# 25::News & Politics
# <class 'dict'>
# 26::Howto & Style
# <class 'dict'>
# 27::Education
# <class 'dict'>
# 28::Science & Technology
# <class 'dict'>
# 29::Nonprofits & Activism
# <class 'dict'>
# 30::Movies
# <class 'dict'>
# 31::Anime/Animation
# <class 'dict'>
# 32::Action/Adventure
# <class 'dict'>
# 33::Classics
# <class 'dict'>
# 34::Comedy
# <class 'dict'>
# 35::Documentary
# <class 'dict'>
# 36::Drama
# <class 'dict'>
# 37::Family
# <class 'dict'>
# 38::Foreign
# <class 'dict'>
# 39::Horror
# <class 'dict'>
# 40::Sci-Fi/Fantasy
# ...

# %%
type(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8584777fc013> in <module>
# ----> 1 type(name)
#
# NameError: name 'name' is not defined

# %%
name[1]

# %%
df = pd.read_json('youtube_data/US_category_id.json')
df.head(5)
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"m2...

# %%
df2 = pd.DataFrame(usCatergory['items'])
df2.head(5)
# Out:
#                     kind                                               etag  \
# 0  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
# 2  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
# 3  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
# 4  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
#
#    id                                            snippet
# 0   1  {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...
# 1   2  {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...
# 2  10  {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...
# 3  15  {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...
# 4  17  {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'tit...

# %%
temp = df2[['id','snippet']]
temp.set_index('id',inplace=True)
temp['snippet'].transform(lambda x : x['title'])
# Out:
# id
# 1          Film & Animation
# 2          Autos & Vehicles
# 10                    Music
# 15           Pets & Animals
# 17                   Sports
# 18             Short Movies
# 19          Travel & Events
# 20                   Gaming
# 21            Videoblogging
# 22           People & Blogs
# 23                   Comedy
# 24            Entertainment
# 25          News & Politics
# 26            Howto & Style
# 27                Education
# 28     Science & Technology
# 29    Nonprofits & Activism
# 30                   Movies
# 31          Anime/Animation
# 32         Action/Adventure
# 33                 Classics
# 34                   Comedy
# 35              Documentary
# 36                    Drama
# 37                   Family
# 38                  Foreign
# 39                   Horror
# 40           Sci-Fi/Fantasy
# 41                 Thriller
# 42                   Shorts
# 43                    Shows
# 44                 Trailers
# Name: snippet, dtype: object

# %%
files = [i for i in glob.glob('youtube_data/*category_id.json'.format('json'))]
sorted(files)

column_names = ["id", "country", "snippet"]

# Task: Merge all dataframes to single dataframe "combined_data" and add a 'country' column. 
json_dataframe = pd.DataFrame(columns = column_names,index=["id", "country"])

for jsonfile in files:
    jsonDict = {}
    with open(jsonfile) as file:
          jsonDict = json.load(file)
    country = jsonfile.replace('youtube_data','').replace('category_id.json','').replace('/','').replace('_','')
    for obj in usCatergory['items']:
        json_dataframe.loc[len(json_dataframe.index)] = [obj['id'], country, obj['snippet']['title']]    
    
json_dataframe.describe()
# Out:
#          id country snippet
# count   128     128     128
# unique   32       4      31
# top      36      IN  Comedy
# freq      4      32       8

# %%
json_dataframe.drop_duplicates(keep='first', inplace=True)

# %%
json_dataframe.describe()
# Out:
#          id country snippet
# count   128     128     128
# unique   32       4      31
# top      36      IN  Comedy
# freq      4      32       8

# %%
idFilter = json_dataframe['country'] == 'IN'
countryFilter = json_dataframe['id'] == '1'
value = json_dataframe[ idFilter & countryFilter ]['snippet'].iloc[0]

# %%
type(value)
# Out:
# str

# %%
json_dataframe.dtypes
# Out:
# id         object
# country    object
# snippet    object
# dtype: object

# %%
json_dataframe['id']=pd.to_numeric(json_dataframe['id'],downcast='integer')
json_dataframe['id']
# Out:
# id      NaN
# 2       1.0
# 3       2.0
# 4      10.0
# 5      15.0
#        ...
# 125    40.0
# 126    41.0
# 127    42.0
# 128    43.0
# 129    44.0
# Name: id, Length: 129, dtype: float64

# %%
json_dataframe.dtypes
# Out:
# id         float64
# country     object
# snippet     object
# dtype: object

# %%
json_dataframe.drop(json_dataframe.select_dtypes(include=[np.number,np.bool]).columns,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-5394c9e831e9> in <module>
# ----> 1 json_dataframe.drop(json_dataframe.select_dtypes(include=[np.number,np.bool]).columns,inplace=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
json_dataframe
# Out:
#        id country           snippet
# 2     1.0      IN  Film & Animation
# 3     2.0      IN  Autos & Vehicles
# 4    10.0      IN             Music
# 5    15.0      IN    Pets & Animals
# 6    17.0      IN            Sports
# ..    ...     ...               ...
# 125  40.0      US    Sci-Fi/Fantasy
# 126  41.0      US          Thriller
# 127  42.0      US            Shorts
# 128  43.0      US             Shows
# 129  44.0      US          Trailers
#
# [128 rows x 3 columns]

# %%
columns_to_drop = json_dataframe.select_dtypes(include=[np.object]).columns.tolist()

# %%
json_dataframe.drop(columns_to_drop, axis='columns', inplace=True)

# %%
json_dataframe
# Out:
#     country           snippet
# 2        IN  Film & Animation
# 3        IN  Autos & Vehicles
# 4        IN             Music
# 5        IN    Pets & Animals
# 6        IN            Sports
# ..      ...               ...
# 125      US    Sci-Fi/Fantasy
# 126      US          Thriller
# 127      US            Shorts
# 128      US             Shows
# 129      US          Trailers
#
# [128 rows x 2 columns]

# %%
json_dataframe = pd.concat([json_dataframe,pd.get_dummies(json_dataframe['country'],prefix='country',drop_first=True)],axis=1)
json_dataframe.drop(['country'],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-86c3eafed4f2> in <module>
# ...

# %%
json_dataframe.head(5)
# Out:
#             snippet  country_FR  country_IN  country_US  yes_no
# 2  Film & Animation           0           1           0    True
# 3  Autos & Vehicles           0           1           0    True
# 4             Music           0           1           0    True
# 5    Pets & Animals           0           1           0    True
# 6            Sports           0           1           0    True

# %%
json_dataframe['yes_no'] = True

# %%
json_dataframe['yes_no'] = json_dataframe['yes_no'].apply(lambda x: 1 if x else 0)

# %%
json_dataframe['yes_no']
# Out:
# 2      1
# 3      1
# 4      1
# 5      1
# 6      1
#       ..
# 125    1
# 126    1
# 127    1
# 128    1
# 129    1
# Name: yes_no, Length: 128, dtype: int64
